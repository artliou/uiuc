# %%
import pandas as pd
import numpy as np
import os
filepath = "/Users/arthurliou/cs/uiuc/cs598/airline_ontime/test/"
filename = "On_Time_On_Time_Performance_1988_1"
filePathFileName = filepath + filename
outputFile=os.path.join(filePathFileName + "_cleaned.csv")
# files = os.listdir()
# print(files)
df = pd.read_csv(filePathFileName + ".csv")
df.head()

# %%
df.columns

# %%
df.shape

# %%
# df.isnull()
# df = df.astype(object).where(pd.notnull(df),None)

# %%
dropArray = ['Quarter', 'TailNum','OriginCityName', 'OriginState', 'OriginStateFips',
       'OriginStateName', 'OriginWac', 'DestCityName', 'DestState',
       'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15', 'DepartureDelayGroups',
       'DepTimeBlk', 'TaxiOut', 'WheelsOff', 'WheelsOn', 'TaxiIn','ArrDel15',
       'ArrivalDelayGroups', 'ArrTimeBlk', 'Cancelled', 'CancellationCode',
       'Diverted', 'CRSElapsedTime', 'ActualElapsedTime', 'AirTime', 'Flights',
       'Distance', 'DistanceGroup', 'CarrierDelay', 'WeatherDelay', 'NASDelay',
       'SecurityDelay', 'LateAircraftDelay', 'FirstDepTime', 'TotalAddGTime',
       'LongestAddGTime', 'DivAirportLandings', 'DivReachedDest',
       'DivActualElapsedTime', 'DivArrDelay', 'DivDistance', 'Div1Airport',
       'Div1WheelsOn', 'Div1TotalGTime', 'Div1LongestGTime', 'Div1WheelsOff',
       'Div1TailNum', 'Div2Airport', 'Div2WheelsOn', 'Div2TotalGTime',
       'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum', 'Unnamed: 75']

df.drop(dropArray,axis=1,inplace=True)

# %%
df_trim = df.loc[:, ("Year","Month", "DayofMonth", "DayOfWeek", "FlightDate", "UniqueCarrier", "AirlineID", "Carrier", "FlightNum", "Origin", "Dest", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes")]

# convert just columns to numeric type
df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]] = df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]].apply(pd.to_numeric)
# df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]] = df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]] = df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]] = df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]].astype("Int64")

# convert just columns to string type
df_trim[["FlightDate", "UniqueCarrier", "Carrier", "Origin", "Dest"]] = df_trim[["FlightDate", "UniqueCarrier", "Carrier", "Origin", "Dest"]].astype(str)

df_trim.head()

# %%
df_trim.shape

# %%
# Export to CSV with no DF Index, Yes Header, and UTF 8 Encoding
df_trim.to_csv(outputFile, index = False, header=True, encoding='utf-8-sig')
# df_trim.dtypes

# %%
# Cut Down Rows for Testing
# df_trim2 = df.loc[df_trim["Origin"] == "PNS"]
# df_trim2.shape
# df_trim2.head()
# df_trim2.to_csv(outputFile, index=False, header=True, encoding='utf-8-sig')

# %%
import pandas as pd
import numpy as np
import os

filepath = "/Users/arthurliou/cs/uiuc/cs598/airline_ontime/converted/"
targetfilepath = "/Users/arthurliou/cs/uiuc/cs598/airline_ontime/python_cleaned/"
dropArray = ['Quarter', 'TailNum','OriginCityName', 'OriginState', 'OriginStateFips','OriginStateName', 'OriginWac', 'DestCityName', 'DestState','DestStateFips', 'DestStateName', 'DestWac', 'DepDel15', 'DepartureDelayGroups', 'DepTimeBlk', 'TaxiOut', 'WheelsOff', 'WheelsOn', 'TaxiIn','ArrDel15', 'ArrivalDelayGroups', 'ArrTimeBlk', 'Cancelled', 'CancellationCode', 'Diverted', 'CRSElapsedTime', 'ActualElapsedTime', 'AirTime', 'Flights', 'Distance', 'DistanceGroup', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay', 'FirstDepTime', 'TotalAddGTime', 'LongestAddGTime', 'DivAirportLandings', 'DivReachedDest', 'DivActualElapsedTime', 'DivArrDelay', 'DivDistance', 'Div1Airport', 'Div1WheelsOn', 'Div1TotalGTime', 'Div1LongestGTime', 'Div1WheelsOff','Div1TailNum', 'Div2Airport', 'Div2WheelsOn', 'Div2TotalGTime', 'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum', 'Unnamed: 75']

def convertFiles():
    files = os.listdir(filepath)
    print("Files To Process: ", len(files))
#     print(files[0])
    
    for file in files:
        print("Cleaning: ", file)
        filePathFileName = filepath + file
        fileNameNoCSV = file[:-4]
        outputFile=os.path.join(targetfilepath + fileNameNoCSV + "_cleaned.csv")
        df = pd.read_csv(filePathFileName)

#         df.drop(dropArray,axis=1,inplace=True)
        df_trim = df.loc[:, ("Year","Month", "DayofMonth", "DayOfWeek", "FlightDate", "UniqueCarrier", "AirlineID", "Carrier", "FlightNum", "Origin", "Dest", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes")]

        # convert just columns to numeric type
        df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]] = df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]].apply(pd.to_numeric)
        # df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]] = df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]] = df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]] = df_trim[["Year","Month", "DayofMonth", "DayOfWeek", "AirlineID", "FlightNum", "CRSDepTime", "DepTime","DepDelay","DepDelayMinutes", "CRSArrTime", "ArrTime", "ArrDelay", "ArrDelayMinutes"]].astype("Int64")

        # convert just columns to string type
        df_trim[["FlightDate", "UniqueCarrier", "Carrier", "Origin", "Dest"]] = df_trim[["FlightDate", "UniqueCarrier", "Carrier", "Origin", "Dest"]].astype(str)

        df_trim.to_csv(outputFile, index = False, header=True, encoding='utf-8-sig')
        print(outputFile)

convertFiles()
# Out:
# Files To Process:  240
# Cleaning:  On_Time_On_Time_Performance_2001_6.csv
# /Users/arthurliou/cs/uiuc/cs598/airline_ontime/python_cleaned/On_Time_On_Time_Performance_2001_6_cleaned.csv
# Cleaning:  On_Time_On_Time_Performance_1992_4.csv
# /Users/arthurliou/cs/uiuc/cs598/airline_ontime/python_cleaned/On_Time_On_Time_Performance_1992_4_cleaned.csv
# Cleaning:  On_Time_On_Time_Performance_1998_11.csv
# /Users/arthurliou/cs/uiuc/cs598/airline_ontime/python_cleaned/On_Time_On_Time_Performance_1998_11_cleaned.csv
# Cleaning:  On_Time_On_Time_Performance_2003_4.csv
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /Users/arthurliou/cs/uiuc/cs598/airline_ontime/python_cleaned/On_Time_On_Time_Performance_2003_4_cleaned.csv
# Cleaning:  On_Time_On_Time_Performance_1990_6.csv
# ...
